# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import train_upvote_mini.csv file

# %%
df = pd.read_csv("train_upvote_mini.csv")
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %% [markdown]
# ## What is its size?

# %%
df.shape
# Out:
# (15440, 7)

# %% [markdown]
# ## Show the types of each feature

# %%
df.dtypes
# Out:
# ID              int64
# Tag            object
# Reputation    float64
# Answers       float64
# Username        int64
# Views         float64
# Upvotes       float64
# dtype: object

# %% [markdown]
# ## How many unique "tag" available?

# %%
df.Tag.nunique()
# Out:
# 10

# %% [markdown]
# ## Show scatterplot (inherited from matplotlib) and relplot between "views" and "upvotes"

# %%
sns.scatterplot(x='Views',y='Upvotes',data=df)
# Out:
# <AxesSubplot:xlabel='Views', ylabel='Upvotes'>

# %% [markdown]
# ## Plot replot between "Views" and "Upvotes"

# %%
sns.relplot(x='Views',y='Upvotes',data=df)

# %% [markdown]
# ## Plot relplot between "Views" and "Upvotes" with hue as "Tag"

# %%
sns.relplot(x='Views',y='Upvotes',hue='Tag',data=df)

# %% [markdown]
# ## Plot relplot between "Views" and "Upvotes" with hue as "Answers"

# %%
sns.relplot(x='Views',y='Upvotes',data=df,hue='Answers')

# %% [markdown]
# ## Plot relplot between "Views" and "Upvotes" with size as "Tag"

# %%
sns.relplot(x='Views',y='Upvotes',data=df,size='Tag')

# %% [markdown]
# ## Plot line chart using relplot between "Answers" and "Upvotes"

# %%
sns.relplot(x='Answers',y='Upvotes',data=df,kind='line')

# %% [markdown]
# ## Does Reputation score of question author impact no of upvotes?. Draw replot.

# %%
sns.relplot(x='Reputation',y='Upvotes',data=df)
plt.xticks(rotation=60)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.]),
#  [Text(-100000.0, 0, '−100000'),
#   Text(0.0, 0, '0'),
#   Text(100000.0, 0, '100000'),
#   Text(200000.0, 0, '200000'),
#   Text(300000.0, 0, '300000'),
#   Text(400000.0, 0, '400000'),
#   Text(500000.0, 0, '500000'),
#   Text(600000.0, 0, '600000'),
#   Text(700000.0, 0, '700000'),
#   Text(800000.0, 0, '800000')])

# %% [markdown]
# ## 2. Visualizating Categorial Data
# Various Categorial Plots in Seaborn

# %%
df1 = pd.read_csv("train_hr_mini.csv")
df1.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df1.shape
# Out:
# (6397, 14)

# %% [markdown]
# ## Show Jitter plot between education and avg_training_score

# %%
sns.catplot(x='education',y='avg_training_score',data=df1)

# %% [markdown]
# ## Here, there are a lot of deviation from true values of the points that is called Jitter. So, let us make Jitter to false and visualize data.

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,jitter=False)

# %% [markdown]
# ## Plot Swarm plot between education category and avg_training_score

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='swarm')

# %% [markdown]
# ## Show Hue Plot to see the gender distribution in the plot of education category and avg_training_score. Here, hue is "gender".

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,hue='gender',kind='swarm')

# %% [markdown]
# ## Who are all promoted considering education and avg training score?. Draw swarm plot with hue as "is_promoted"

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,hue='is_promoted',kind='swarm')

# %% [markdown]
# ## Draw box plot between education and avg_training_score

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='box')

# %% [markdown]
# ## Who are promoted and not promoted considering education and avg_training_score?. Draw Box Plot.

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='box',hue='is_promoted')

# %% [markdown]
# ## Show violin plot between education categories and avg training score with hue as "is_promoted" target variable

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='violin',hue='is_promoted')

# %% [markdown]
# ## Draw Violin plot with only 2 hue levels, use split attribute

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='violin',split=True,hue='is_promoted')

# %% [markdown]
# ## Using catplot(), draw a Bar Chart between "education" and "avg_training_score", with hue as "is_promoted"

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='bar',hue='is_promoted')

# %% [markdown]
# ## Show point plot between education and avg training score with hue promotion category

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='point',hue='is_promoted')

# %% [markdown]
# ## Draw swarm plot for education, avg training score, hue as is_promoted for male and female category

# %%
sns.catplot(x='education',y='avg_training_score',data=df1,kind='swarm',hue='is_promoted',col='gender')

# %% [markdown]
# ## 3. Visualizing the Distribution of Data
# ### Plot Univariate Distributions

# %% [markdown]
# ## Plot Histogram with kernel density estimate value for age attribute

# %%
sns.distplot(df1.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## Show only Histogram for age variable, without KDE

# %%
sns.distplot(df1.age,kde=False)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Plot Bivariate Distributions

# %% [markdown]
# ## Draw a joint plot between avg_training_score and age

# %%
sns.jointplot(x='avg_training_score',y='age',data=df1)

# %% [markdown]
# ## Draw a hexplot for depicting the relationship between avg training score and age

# %%
sns.jointplot(x='avg_training_score',y='age',data=df1,kind='hex')

# %% [markdown]
# ## Show KDE Plot to visualize age vs avg training score

# %%
sns.jointplot(x='age',y='avg_training_score',data=df1,kind='kde')

# %% [markdown]
# ## Draw heatmap for the dataset

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Draw Boxen Plot between "age" and "avg_training_score, with hue "is_promoted"

# %%
plt.figure(figsize=(14,7))
sns.catplot(x='age',y='avg_training_score',data=df1,kind='boxen',hue='is_promoted',height=4,aspect=3)

# %% [markdown]
# ## Draw a Pair Plot for the dataset

# %%
sns.pairplot(df1)
